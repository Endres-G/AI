# %% [markdown]
# <a href="https://colab.research.google.com/github/Endres-G/AI/blob/main/C%C3%B3pia_de_simple_neuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def sigmoid(x):
  return 1.0 / (1 + np.exp(-x))

# %%
x = np.linspace(-5.0, 5.0)
y = sigmoid(x)

# %%
plt.plot(x,y)

# %%
class Neuron:
  def __init__(self, input_size=5):
    self.w = np.random.random(input_size)
    self.b = np.random.random()
  def compute(self, inputs):
    s = np.dot(self.w,inputs) + self.b
    z = sigmoid(s)
    return z

# %%
n = Neuron()
n.compute([1,2,3,4,5])

# %%
import numpy as np

class Neuron:
    def __init__(self, weights, bias):
        self.w = np.array(weights)
        self.b = bias

    def compute(self, inputs):
        s = np.dot(self.w, inputs) + self.b
        z = np.tanh(s)
        return z

n = Neuron(weights=[-1, 0, 1], bias=-0.5)

output = n.compute([1, 255550, 3])
print(f"{output:.4f}")
# Out:
# 0.9051
